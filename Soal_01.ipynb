# %% [markdown]
# <a href="https://colab.research.google.com/github/Gede-Anggara/Struktur-Data-A/blob/main/Soal_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Sistem pengelolaan nilai mahasiswa menggunakan array

# %%
nilai = []

# %% [markdown]
# Input 10 nilai mahasiswa

# %%
for i in range(10):
  n = int(input("Masukkan nilai mahasiswa ke-" + str(i+1) + ": "))
  nilai.append(n)
# Out:
# Masukkan nilai mahasiswa ke-1: 99
# Masukkan nilai mahasiswa ke-2: 98
# Masukkan nilai mahasiswa ke-3: 78
# Masukkan nilai mahasiswa ke-4: 77
# Masukkan nilai mahasiswa ke-5: 76
# Masukkan nilai mahasiswa ke-6: 56
# Masukkan nilai mahasiswa ke-7: 49
# Masukkan nilai mahasiswa ke-8: 69
# Masukkan nilai mahasiswa ke-9: 54
# Masukkan nilai mahasiswa ke-10: 90

# %% [markdown]
# Nilai tertinggi, terendah, dan rata-rata

# %%
nilai_tertinggi = max(nilai)
nilai_terendah = min(nilai)
rata_rata = sum(nilai)/len(nilai)

# %% [markdown]
# Hitung jumlah mahasiswa yang lulus

# %%
lulus = 0
for n in nilai:
  if n >= 60:
    lulus +=1

tidak_lulus = len(nilai) - lulus

# %% [markdown]
# Output

# %%
print("\n===== Hasil nilai akhir =====")
print("Data nilai:", nilai)
print("Nilai tertinggi:", nilai_tertinggi)
print("Nilai terendah:", nilai_terendah)
print("Nilai rata-rata:", rata_rata)
print("Jumlah mahasiswa yang lulus:", lulus)
print("Jumlah mahasiswa yang tidak lulus:", tidak_lulus)
# Out:
# ===== Hasil nilai akhir =====
# Data nilai: [99, 98, 78, 77, 76, 56, 49, 69, 54, 90]
# Nilai tertinggi: 99
# Nilai terendah: 49
# Nilai rata-rata: 74.6
# Jumlah mahasiswa yang lulus: 7
# Jumlah mahasiswa yang tidak lulus: 3
